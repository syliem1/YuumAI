# %%
import sagemaker

role = sagemaker.get_execution_role()
print(role)
# Out:
# sagemaker.config INFO - Fetched defaults config from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.Session.DefaultS3Bucket
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.Session.DefaultS3ObjectKeyPrefix
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.Session.DefaultS3Bucket
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.Session.DefaultS3ObjectKeyPrefix
# arn:aws:iam::768394660366:role/datazone_usr_role_5i1vmxossv3f2o_b1rxf3f1mnfnv4

# %%
# !python3 prepare_training_data.py --database lol_coach_db --output-bucket lol-coach-processed-data --model all --region us-west-2
# Out:
# Starting training data preparation...
# Database: lol_coach_db
# Output bucket: lol-coach-processed-data
#
# ============================================================
# PREPARING PLAYSTYLE PROFILER TRAINING DATA
# ============================================================
# Running query:
#         SELECT
#             pa.game_name,
#             pa.tagline,
#             pa.total_games,
#      ...
# Waiting for query 4b7d44a8-5da6-4c4f-a3f2-ae26df4f8ced...
# Query succeeded in 1045.4s
# Retrieved 23545 rows
#
# Dataset summary:
#   Players: 23,545
#   Features: 32
#   Avg games per player: 19.3
#   Win rate range: 0.0% - 100.0%
#
# Split summary:
#   Training set: 18,836 samples
#   Validation set: 4,709 samples
#
# Uploading to s3://lol-coach-processed-data/training/player_features_train.parquet...
# Saved to s3://lol-coach-processed-data/training/player_features_train.parquet
#
# Uploading to s3://lol-coach-processed-data/training/player_features_val.parquet...
# Saved to s3://lol-coach-processed-data/training/player_features_val.parquet
#
# ============================================================
# PREPARING HYPOTHETICAL SIMULATOR TRAINING DATA
# ============================================================
# Running query:
#         WITH team_stats AS (
#             SELECT
#                 match_id,
#                 team_id,...
# Waiting for query a3787ff2-91b6-4e33-b263-d88e1ee976c5...
# Query succeeded in 970.2s
# Retrieved 145107 rows
#
# Dataset summary:
#   Match states: 145,107
#   Blue team win rate: 51.2%
#
# Split summary:
#   Training set: 116,085 samples
#   Validation set: 29,022 samples
#
# Uploading to s3://lol-coach-processed-data/training/teamfight_data_train.parquet...
# Saved to s3://lol-coach-processed-data/training/teamfight_data_train.parquet
#
# Uploading to s3://lol-coach-processed-data/training/teamfight_data_val.parquet...
# Saved to s3://lol-coach-processed-data/training/teamfight_data_val.parquet
#
# Uploading to s3://lol-coach-processed-data/training/training_metadata.json...
# Saved to s3://lol-coach-processed-data/training/training_metadata.json
#
# ============================================================
# TRAINING DATA PREPARATION COMPLETE
# ============================================================
#
# playstyle_profiler:
#   Train: s3://lol-coach-processed-data/training/player_features_train.parquet
#   Val: s3://lol-coach-processed-data/training/player_features_val.parquet
#   Samples: 18,836 train, 4,709 val
#
# hypothetical_simulator:
#   Train: s3://lol-coach-processed-data/training/teamfight_data_train.parquet
#   Val: s3://lol-coach-processed-data/training/teamfight_data_val.parquet
#   Samples: 116,085 train, 29,022 val
#
# Done! Training data is ready for SageMaker.

# %%
# !python3 sagemaker_deployment.py \
  --role-arn arn:aws:iam::768394660366:role/datazone_usr_role_5i1vmxossv3f2o_b1rxf3f1mnfnv4 \
  --bucket lol-coach-processed-data \
  --action train-profiler \
  --training-data s3://lol-coach-processed-data/training/
# Out:
# sagemaker.config INFO - Fetched defaults config from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.Session.DefaultS3Bucket
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.Session.DefaultS3ObjectKeyPrefix
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.Session.DefaultS3Bucket
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.Session.DefaultS3ObjectKeyPrefix
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.VpcConfig.Subnets
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.VpcConfig.SecurityGroupIds
# INFO:sagemaker:Creating training-job with name: sagemaker-scikit-learn-2025-11-05-03-06-41-484
# 2025-11-05 03:06:44 Starting - Starting the training job...
# 2025-11-05 03:07:01 Starting - Preparing the instances for training...
# 2025-11-05 03:07:27 Downloading - Downloading input data...
# 2025-11-05 03:07:57 Downloading - Downloading the training image......
# 2025-11-05 03:08:57 Training - Training image download completed. Training in progress./miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 2025-11-05 03:09:00,338 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2025-11-05 03:09:00,343 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2025-11-05 03:09:00,346 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2025-11-05 03:09:00,362 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2025-11-05 03:09:00,692 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2025-11-05 03:09:00,696 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2025-11-05 03:09:00,714 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2025-11-05 03:09:00,716 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2025-11-05 03:09:00,733 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2025-11-05 03:09:00,736 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2025-11-05 03:09:00,751 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-1"
#     ],
#     "current_instance_type": "ml.m5.large",
#     "distribution_hosts": [],
#     "distribution_instance_groups": [],
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "n-clusters": 13
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.m5.large",
#             "hosts": [
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "is_smddpmprun_installed": false,
#     "is_smddprun_installed": false,
#     "job_name": "sagemaker-scikit-learn-2025-11-05-03-06-41-484",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://lol-coach-processed-data/sagemaker-scikit-learn-2025-11-05-03-06-41-484/source/sourcedir.tar.gz",
#     "module_name": "playstyle_profiler_training",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "num_neurons": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.large",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.large",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0",
#         "topology": null
#     },
#     "user_entry_point": "playstyle_profiler_training.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"n-clusters":13}
# SM_USER_ENTRY_POINT=playstyle_profiler_training.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0","topology":null}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_CURRENT_INSTANCE_TYPE=ml.m5.large
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# SM_IS_HETERO=false
# SM_MODULE_NAME=playstyle_profiler_training
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_NUM_NEURONS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://lol-coach-processed-data/sagemaker-scikit-learn-2025-11-05-03-06-41-484/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-1"],"current_instance_type":"ml.m5.large","distribution_hosts":[],"distribution_instance_groups":[],"framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"n-clusters":13},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"is_smddpmprun_installed":false,"is_smddprun_installed":false,"job_name":"sagemaker-scikit-learn-2025-11-05-03-06-41-484","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://lol-coach-processed-data/sagemaker-scikit-learn-2025-11-05-03-06-41-484/source/sourcedir.tar.gz","module_name":"playstyle_profiler_training","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"num_neurons":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0","topology":null},"user_entry_point":"playstyle_profiler_training.py"}
# SM_USER_ARGS=["--n-clusters","13"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_N-CLUSTERS=13
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python39.zip:/miniconda3/lib/python3.9:/miniconda3/lib/python3.9/lib-dynload:/miniconda3/lib/python3.9/site-packages:/miniconda3/lib/python3.9/site-packages/setuptools/_vendor
# Invoking script with the following command:
# /miniconda3/bin/python playstyle_profiler_training.py --n-clusters 13
# 2025-11-05 03:09:00,753 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker Debugger as it is not installed.
# 2025-11-05 03:09:00,754 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker TF as Tensorflow is not installed.
# Starting SageMaker training script...
# Training Runeterra Regional Playstyle Classifier
# Training data path: /opt/ml/input/data/train
# Model output path: /opt/ml/model
# Number of regions: 13
# Loading data...
# Loaded 18836 rows.
# Engineering regional features...
# Training clustering model with 13 regions...
# Using 20 features for clustering.
# Regional features: ['bandle', 'bilgewater', 'demacia', 'ionia', 'ixtal', 'noxus', 'piltover', 'shadow_isles', 'shurima', 'targon', 'freljord', 'void', 'zaun']
# Clustering complete. Silhouette Score: 0.12783187354863057
# ============================================================
# REGION ASSIGNMENTS:
# ============================================================
# Bandle City          | Players:  1452 | Win Rate: 58.66%
# Demacia              | Players:   792 | Win Rate: 49.01%
# Zaun                 | Players:  1844 | Win Rate: 41.69%
# The Freljord         | Players:  1558 | Win Rate: 51.87%
# Shurima              | Players:  1208 | Win Rate: 47.73%
# Piltover             | Players:  2278 | Win Rate: 50.51%
# Noxus                | Players:  2313 | Win Rate: 47.85%
# Targon               | Players:   431 | Win Rate: 54.82%
# Shadow Isles         | Players:   796 | Win Rate: 56.72%
# The Void             | Players:  2961 | Win Rate: 49.77%
# Ixtal                | Players:  1008 | Win Rate: 57.19%
# Ionia                | Players:  1330 | Win Rate: 47.22%
# Bilgewater           | Players:   865 | Win Rate: 58.68%
# ============================================================
# Saving model to /opt/ml/model...
# Training completed successfully
# Model artifacts saved to /opt/ml/model
# 2025-11-05 03:09:17,773 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2025-11-05 03:09:35 Uploading - Uploading generated training model
# 2025-11-05 03:09:35 Completed - Training job completed
# Training seconds: 129
# Billable seconds: 129
# Training job completed: sagemaker-scikit-learn-2025-11-05-03-06-41-484
# Model trained and saved to: s3://lol-coach-processed-data/models/playstyle-profiler/sagemaker-scikit-learn-2025-11-05-03-06-41-484/output/model.tar.gz

# %%
# !python3 dynamodb_schemas.py
# Out:
# Creating table: lol-timeline-events
# Waiting for lol-timeline-events to become active...
# ✓ Table lol-timeline-events created successfully
# Creating table: lol-timeline-ai-summaries
# Waiting for lol-timeline-ai-summaries to become active...
# ✓ Table lol-timeline-ai-summaries created successfully
# Applying TTL settings to lol-timeline-ai-summaries...
# ✓ TTL enabled for lol-timeline-ai-summaries
# Creating table: lol-timeline-user-questions
# Waiting for lol-timeline-user-questions to become active...
# ✓ Table lol-timeline-user-questions created successfully
# Applying TTL settings to lol-timeline-user-questions...
# ✓ TTL enabled for lol-timeline-user-questions
# Creating table: lol-player-timeline-metadata
# Waiting for lol-player-timeline-metadata to become active...
# ✓ Table lol-player-timeline-metadata created successfully
